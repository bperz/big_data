# %%
import re, nltk

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud
from PIL import Image

# %%
with open("Quo_vadis.txt", encoding="utf8") as myfile:
    data = " ".join(line.rstrip() for line in myfile)

# %%
print(data[:200])
# Out:
# Henryk Sienkiewicz  Quo vadis  ISBN 978-83-288-2832-2     Rozdział pierwszy  Petroniusz obudził się zaledwie koło południa i jak zwykle, zmęczony bardzo. Poprzedniego dnia był na uczcie u Nerona, któr

# %%
# ?nltk

# %%
subbed = re.sub(r"[^\w]+", " ", data).lower()

# %%
print(subbed[:250])
# Out:
# henryk sienkiewicz quo vadis isbn 978 83 288 2832 2 rozdział pierwszy petroniusz obudził się zaledwie koło południa i jak zwykle zmęczony bardzo poprzedniego dnia był na uczcie u nerona która przeciągnęła się do późna w noc od pewnego czasu zdrowie j

# %%
with open("polish_stopwords.txt", encoding="utf8") as myfile:
    stop_text = " ".join(line.rstrip() for line in myfile)

stopWords = set(stop_text.split(" "))

# %%
# with open("stop.txt", encoding="utf8", mode='w') as myfile:
#     for item in sorted(list(stopWords)):
#         myfile.write(item + '\n')

# %%
text = subbed.split(" ")

# %%
text = [w for w in text if w not in stopWords and len(w) > 1 and w[0] != "'"]

# %%
print(text[:250])
# Out:
# ['henryk', 'sienkiewicz', 'quo', 'vadis', 'isbn', '978', '83', '288', '2832', 'rozdział', 'pierwszy', 'petroniusz', 'obudził', 'zaledwie', 'koło', 'południa', 'zwykle', 'zmęczony', 'poprzedniego', 'dnia', 'uczcie', 'nerona', 'przeciągnęła', 'późna', 'noc', 'pewnego', 'czasu', 'zdrowie', 'zaczęło', 'psuć', 'mówił', 'rankami', 'budzi', 'zdrętwiały', 'możności', 'zebrania', 'myśli', 'poranna', 'kąpiel', 'staranne', 'wygniatanie', 'ciała', 'wprawionych', 'niewolników', 'przyśpieszało', 'stopniowo', 'obieg', 'leniwej', 'krwi', 'rozbudzało', 'cuciło', 'wracało', 'siły', 'elaeothesium', 'ostatniego', 'kąpielowego', 'przedziału', 'wychodził', 'wskrzeszony', 'oczami', 'błyszczącymi', 'dowcipem', 'wesołością', 'odmłodzon', 'pełen', 'życia', 'wykwintny', 'niedościgniony', 'otho', 'mógł', 'porównać', 'prawdziwy', 'nazywano', 'arbiter', 'elegantiarum', 'łaźniach', 'publicznych', 'bywał', 'rzadko', 'chyba', 'zdarzył', 'budzący', 'podziw', 'retor', 'mówiono', 'mieście', 'efebiach', 'odbywały', 'wyjątkowo', 'zajmujące', 'zapasy', 'zresztą', 'swej', 'insuli', 'własne', 'kąpiele', 'słynny', 'wspólnik', 'sewerusa', 'celer', 'rozszerzył', 'przebudował', 'urządził', 'nadzwyczajnym', 'smakiem', 'nero', 'przyznawał', 'wyższość', 'cezariańskimi', 'chociaż', 'cezariańskie', 'obszerniejsze', 'urządzone', 'nierównie', 'większym', 'przepychem', 'owej', 'uczcie', 'znudziwszy', 'błaznowaniem', 'watyniusza', 'brał', 'wraz', 'neronem', 'lukanem', 'senecjonem', 'udział', 'diatrybie', 'kobieta', 'duszę', 'wstawszy', 'późno', 'zażywał', 'zwykle', 'kąpieli', 'ogromni', 'balneatorzy', 'złożyli', 'cyprysowej', 'mensie', 'pokrytej', 'śnieżnym', 'egipskim', 'byssem', 'dłońmi', 'maczanymi', 'wonnej', 'oliwie', 'poczęli', 'nacierać', 'kształtne', 'ciało', 'zamkniętymi', 'oczyma', 'czekał', 'ciepło', 'laconicum', 'ciepło', 'rąk', 'przejdzie', 'usunie', 'zeń', 'znużenie', 'pewnym', 'czasie', 'przemówił', 'otworzywszy', 'oczy', 'jął', 'rozpytywać', 'pogodę', 'następnie', 'gemmy', 'jubiler', 'idomen', 'obiecał', 'przysłać', 'dzień', 'dzisiejszy', 'obejrzenia', 'pokazało', 'pogoda', 'piękna', 'połączona', 'lekkim', 'powiewem', 'gór', 'albańskich', 'gemmy', 'przyszły', 'petroniusz', 'przymknął', 'oczy', 'wydał', 'rozkaz', 'przeniesiono', 'tepidarium', 'wtem', 'spoza', 'kotary', 'wychylił', 'nomenclator', 'oznajmiając', 'młody', 'markus', 'winicjusz', 'przybyły', 'świeżo', 'azji', 'mniejszej', 'przyszedł', 'odwiedzić', 'petroniusz', 'kazał', 'wpuścić', 'gościa', 'tepidarium', 'przeniósł', 'winicjusz', 'synem', 'starszej', 'siostry', 'laty', 'wyszła', 'marka', 'winicjusza', 'męża', 'konsularnego', 'czasów', 'tyberiuszowych', 'młody', 'służył', 'obecnie', 'korbulonem', 'przeciw', 'partom', 'ukończonej', 'wojnie', 'wracał', 'miasta', 'petroniusz', 'pewną', 'słabość', 'graniczącą', 'przywiązaniem', 'albowiem', 'markus', 'pięknym', 'atletycznym', 'młodzieńcem']

# %%
count = {}
for word in text:
    count.setdefault(word, 0)
    count[word] = count[word] + 1

# %%
counts_list = [(word, c) for word, c in zip(count.keys(), count.values())]
counts_list.sort(key = lambda x: x[1], reverse=True)
print(counts_list[:200])
# Out:
# [('winicjusz', 612), ('rzekł', 538), ('petroniusz', 424), ('począł', 307), ('chwili', 302), ('panie', 291), ('domu', 281), ('cezara', 263), ('czym', 262), ('cezar', 259), ('winicjusza', 256), ('ligia', 237), ('ligii', 233), ('mógł', 231), ('oczy', 229), ('mówił', 217), ('albowiem', 205), ('wówczas', 190), ('nero', 185), ('ludzi', 184), ('wreszcie', 175), ('ligię', 165), ('którą', 163), ('odpowiedział', 153), ('siebie', 151), ('ludzie', 148), ('chilo', 147), ('zarazem', 142), ('głowę', 138), ('ręce', 134), ('chciał', 133), ('ów', 132), ('myśl', 128), ('ni', 128), ('twarz', 126), ('tymczasem', 126), ('wiem', 123), ('ursus', 119), ('śmierć', 117), ('życie', 115), ('duszy', 115), ('akte', 115), ('człowiek', 114), ('nagle', 114), ('miasta', 113), ('petroniusza', 112), ('chwilę', 109), ('odrzekł', 108), ('potem', 108), ('chrystusa', 107), ('rzymie', 105), ('dotąd', 102), ('rzym', 102), ('głowy', 101), ('śmierci', 100), ('życia', 96), ('mówić', 95), ('miasto', 95), ('lud', 95), ('chrześcijan', 95), ('miłość', 94), ('świat', 92), ('czas', 92), ('razem', 92), ('chrystus', 91), ('dalej', 90), ('piotr', 89), ('chrześcijanie', 88), ('widział', 86), ('poczęła', 86), ('czasu', 85), ('dopiero', 85), ('wiesz', 85), ('spytał', 85), ('niewolników', 82), ('nikt', 82), ('rzymu', 81), ('serce', 81), ('twarzy', 80), ('apostoł', 80), ('wprawdzie', 79), ('choćby', 79), ('dom', 79), ('bogów', 78), ('inni', 78), ('rozdział', 77), ('dzień', 77), ('poczęły', 77), ('eunice', 77), ('zawołał', 76), ('nocy', 75), ('miłości', 75), ('mogła', 75), ('głosem', 75), ('widok', 75), ('całe', 74), ('ancjum', 74), ('wraz', 73), ('zdawało', 73), ('głos', 73), ('rękę', 72), ('chwila', 72), ('słowa', 72), ('czuł', 71), ('chwilami', 71), ('bóg', 71), ('masz', 70), ('jaką', 70), ('poczęli', 69), ('wobec', 69), ('mogę', 68), ('rzeczy', 67), ('takim', 67), ('ziemi', 67), ('zresztą', 66), ('kazał', 66), ('nerona', 65), ('swą', 65), ('głowie', 65), ('myśli', 64), ('imię', 64), ('pomponii', 64), ('piersi', 64), ('atrium', 64), ('pierwszy', 63), ('zupełnie', 63), ('dni', 63), ('zwrócił', 63), ('usta', 63), ('niewolnicy', 63), ('lepiej', 62), ('chcę', 62), ('całą', 62), ('świata', 62), ('jakieś', 62), ('chilona', 62), ('noc', 61), ('oczyma', 61), ('inaczej', 61), ('wprost', 61), ('tygellinus', 61), ('jakoż', 61), ('podniósł', 61), ('serca', 61), ('ostrianum', 61), ('koło', 60), ('bogowie', 60), ('świecie', 60), ('aulusów', 60), ('widocznie', 60), ('następnie', 59), ('czego', 59), ('zbyt', 59), ('winicjuszowi', 59), ('drodze', 59), ('woli', 59), ('rzekła', 59), ('przecie', 59), ('tyle', 58), ('jesteś', 58), ('pomponia', 58), ('pomyślał', 58), ('życiu', 55), ('strony', 55), ('chcąc', 55), ('jednej', 55), ('ust', 54), ('widziałem', 54), ('patrzeć', 54), ('mieć', 53), ('wiedział', 53), ('poppea', 53), ('aulus', 53), ('słów', 53), ('widzieć', 53), ('słyszał', 53), ('mieście', 52), ('swej', 52), ('przeciw', 52), ('umiał', 52), ('znak', 52), ('tłumy', 52), ('ligio', 52), ('prócz', 51), ('patrzył', 51), ('istotnie', 51), ('niemal', 51), ('jutro', 51), ('stało', 51), ('apostoła', 51), ('młody', 50), ('mniej', 50), ('dzieci', 50), ('szczęście', 50), ('chilon', 50), ('paweł', 50), ('nieco', 49), ('powodu', 49), ('mówię', 49), ('całym', 49)]

# %%
counts_list[0:48]
# Out:
# [('winicjusz', 612),
#  ('rzekł', 538),
#  ('petroniusz', 424),
#  ('począł', 307),
#  ('chwili', 302),
#  ('panie', 291),
#  ('domu', 281),
#  ('cezara', 263),
#  ('czym', 262),
#  ('cezar', 259),
#  ('winicjusza', 256),
#  ('ligia', 237),
#  ('ligii', 233),
#  ('mógł', 231),
#  ('oczy', 229),
#  ('mówił', 217),
#  ('albowiem', 205),
#  ('wówczas', 190),
#  ('nero', 185),
#  ('ludzi', 184),
#  ('wreszcie', 175),
#  ('ligię', 165),
#  ('którą', 163),
#  ('odpowiedział', 153),
#  ('siebie', 151),
#  ('ludzie', 148),
#  ('chilo', 147),
#  ('zarazem', 142),
#  ('głowę', 138),
#  ('ręce', 134),
#  ('chciał', 133),
#  ('ów', 132),
#  ('myśl', 128),
#  ('ni', 128),
#  ('twarz', 126),
#  ('tymczasem', 126),
#  ('wiem', 123),
#  ('ursus', 119),
#  ('śmierć', 117),
#  ('życie', 115),
#  ('duszy', 115),
#  ('akte', 115),
#  ('człowiek', 114),
#  ('nagle', 114),
#  ('miasta', 113),
#  ('petroniusza', 112),
#  ('chwilę', 109),
#  ('odrzekł', 108)]

# %%
wc_dict = {w: c for w,c in counts_list[10:72]}

# %%
mask = np.array(Image.open("storm.png"))

# %%
cloud = WordCloud(background_color="white", mask=mask, max_words=100)

# %%
cloud.generate_from_frequencies(wc_dict)

# %%
plt.imshow(cloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 839.5, 754.5, -0.5)

# %%
cloud.to_file("long_q_cloud.png")
